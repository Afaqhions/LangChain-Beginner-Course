# %% [markdown]
# Creating Simple AI agent

# %%
import os

from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
# Initiating model

from langchain.chat_models import init_chat_model

model = init_chat_model(
    model = "llama-3.1-8b-instant",
    model_provider = "groq",
)

res = model.invoke("Hello, how are you?")
res  # Tht Type of AI response is AIMessage
print(res.content)
# Out:
# I'm functioning properly, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm here to help and provide information. How can I assist you today?

# %% [markdown]
# Batch in GenAI ---
# A batch is simply a group of examples or requests processed together in one operation.

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model = "llama-3.1-8b-instant",
    model_provider = "groq",
)

responses = model.batch([
    'Who are You?',
    'What is the capital of France?',
    'What is the meaning of life?'
])

print(responses)

for res in responses:
    print(res.content)
# Out:
# [AIMessage(content="I'm an artificial intelligence model known as a Large Language Model (LLM). I'm a computer program designed to process and generate human-like text based on the input I receive. I'm a type of conversational AI, which means I can understand and respond to natural language queries, answer questions, and engage in discussions.\n\nI don't have a personal identity or emotions like humans do, but I'm designed to be helpful, informative, and neutral. My primary goal is to assist users by providing accurate and relevant information on a wide range of topics, from science and history to entertainment and culture.\n\nI'm constantly learning and improving through machine learning algorithms and large datasets of text. This allows me to stay up-to-date with the latest knowledge and developments in various fields, making me a valuable resource for users seeking information or answers.\n\nHow can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 174, 'prompt_tokens': 39, 'total_tokens': 213, 'completion_time': 0.286082666, 'completion_tokens_details': None, 'prompt_time': 0.007324609, 'prompt_tokens_details': None, 'queue_time': 0.052154691, 'total_time': 0.293407275}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ce6ce-521c-73d0-b496-3614a2a7b057-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 174, 'total_tokens': 213}), AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.004268688, 'completion_tokens_details': None, 'prompt_time': 0.042890226, 'prompt_tokens_details': None, 'queue_time': 0.018561369, 'total_time': 0.047158914}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ce6ce-521d-7a72-b5f3-89079f5c8ff0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50}), AIMessage(content="The question of the meaning of life is one of the most profound and enduring questions in human history. It has been explored and debated by philosophers, theologians, scientists, and thinkers across various cultures and disciplines. While there is no one definitive answer, here are some perspectives on the meaning of life:\n\n**Philosophical Perspectives:**\n\n1. **Existentialism**: The meaning of life is created by each individual through their choices and actions. It's a subjective, personal experience that gives life significance.\n2. **Absurdism**: Life has no inherent meaning, and we must create our own purpose in the face of an uncertain and often seemingly meaningless universe.\n3. **Hedonism**: The meaning of life is to seek pleasure and happiness, either individually or in the company of others.\n\n**Religious Perspectives:**\n\n1. **Theism**: The meaning of life is to fulfill God's will, worship, and serve a higher power.\n2. **Buddhism**: The meaning of life is to attain enlightenment, escape suffering, and find inner peace.\n3. **Christianity**: The meaning of life is to love and serve others, follow Jesus' teachings, and ultimately attain salvation.\n\n**Scientific Perspectives:**\n\n1. **Biological Perspective**: The meaning of life is to survive and reproduce, ensuring the continuation of one's genetic lineage.\n2. **Evolutionary Perspective**: The meaning of life is to adapt to one's environment, maximize fitness, and contribute to the evolution of one's species.\n\n**Humanistic Perspectives:**\n\n1. **Personal Growth**: The meaning of life is to learn, grow, and self-actualize, realizing one's full potential.\n2. **Social Connection**: The mean ...
# I'm an artificial intelligence model known as a Large Language Model (LLM). I'm a computer program designed to process and generate human-like text based on the input I receive. I'm a type of conversational AI, which means I can understand and respond to natural language queries, answer questions, and engage in discussions.
#
# I don't have a personal identity or emotions like humans do, but I'm designed to be helpful, informative, and neutral. My primary goal is to assist users by providing accurate and relevant information on a wide range of topics, from science and history to entertainment and culture.
#
# I'm constantly learning and improving through machine learning algorithms and large datasets of text. This allows me to stay up-to-date with the latest knowledge and developments in various fields, making me a valuable resource for users seeking information or answers.
#
# How can I help you today?
# The capital of France is Paris.
# The question of the meaning of life is one of the most profound and enduring questions in human history. It has been explored and debated by philosophers, theologians, scientists, and thinkers across various cultures and disciplines. While there is no one definitive answer, here are some perspectives on the meaning of life:
#
# **Philosophical Perspectives:**
#
# 1. **Existentialism**: The meaning of life is created by each individual through their choices and actions. It's a subjective, personal experience that gives life significance.
# 2. **Absurdism**: Life has no inherent meaning, and we must create our own purpose in the face of an uncertain and often seemingly meaningless universe.
# 3. **Hedonism**: The meaning of life is to seek pleasure and happiness, either individually or in the company of others.
#
# **Religious Perspectives:**
#
# 1. **Theism**: The meaning of life is to fulfill God's will, worship, and serve a higher power.
# 2. **Buddhism**: The meaning of life is to attain enlightenment, escape suffering, and find inner peace.
# 3. **Christianity**: The meaning of life is to love and serve others, follow Jesus' teachings, and ultimately attain salvation.
#
# **Scientific Perspectives:**
#
# 1. **Biological Perspective**: The meaning of life is to survive and reproduce, ensuring the continuation of one's genetic lineage.
# 2. **Evolutionary Perspective**: The meaning of life is to adapt to one's environment, maximize fitness, and contribute to the evolution of one's species.
#
# **Humanistic Perspectives:**
#
# 1. **Personal Growth**: The meaning of life is to learn, grow, and self-actualize, realizing one's full potential.
# 2. **Social Connection**: The meaning of life is to form meaningful relationships, build communities, and contribute to the greater good.
# 3. **Purpose**: The meaning of life is to have a clear sense of direction, pursue one's passions, and make a positive impact on the world.
#
# Ultimately, the meaning of life is a deeply personal and subjective question that each individual must answer for themselves. It may involve a combination of these perspectives or a unique synthesis of values, experiences, and beliefs.
#
# What do you think is the meaning of life?
