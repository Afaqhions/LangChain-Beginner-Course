# %% [markdown]
# ### Communication with LLM's

# %%
import langchain

# %%
import dotenv
dotenv.load_dotenv()

# %% [markdown]
# ### Chattaing with Groq Model

# %%
from langchain_groq import ChatGroq

# llama-3.1-8b-instant --> Groq Model

model = ChatGroq(model_name = "llama-3.1-8b-instant")

response = model.invoke("Hello, how are you?")
print(response.content)

# %% [markdown]
# ### Chatting with Gemini Flash 2.5

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")

res = model.invoke("Hello, how are you?")
print(res.content)

# %% [markdown]
# Creating Gen AI Apllication with LLM

# %%
import os
import dotenv
dotenv.load_dotenv()
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model(
    model="gemini-2.5-flash-lite",
    model_provider="google_genai")

res = model.invoke("Hello, how are you?")
print(res.content)

# %% [markdown]
# Creating Gen AI Application using Groq

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model(
    model="llama-3.1-8b-instant",
    model_provider="groq"
)

res = model.invoke("Hello, how are you?")
print(res.content)
